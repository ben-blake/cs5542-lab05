# %% [markdown]
# <a href="https://colab.research.google.com/github/ben-blake/cs5542-lab05/blob/main/notebooks/week5_snowflake_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CS 5542 — Week 5 Snowflake Pipeline Notebook
# This notebook is a **demo artifact**: connect → load → query → visualize.
# Replace the example tables with your project subset tables.

# %% [markdown]
# ## 1) Setup
# - Copy `.env.example` to `.env` and fill in your Snowflake credentials.
# - Install dependencies: `pip install -r requirements.txt`

# %%
from scripts.sf_connect import get_conn
import pandas as pd
conn = get_conn()
conn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-775955844.py in <cell line: 0>()
# ----> 1 from scripts.sf_connect import get_conn
#       2 import pandas as pd
#       3 conn = get_conn()
#       4 conn
#
# ModuleNotFoundError: No module named 'scripts'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## 2) Sanity check: list tables

# %%
pd.read_sql('SHOW TABLES IN SCHEMA CS5542_WEEK5.PUBLIC', conn).head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4049228189.py in <cell line: 0>()
# ----> 1 pd.read_sql('SHOW TABLES IN SCHEMA CS5542_WEEK5.PUBLIC', conn).head()
#
# NameError: name 'pd' is not defined

# %% [markdown]
# ## 3) Query examples

# %%
q = '''
SELECT TEAM, CATEGORY, COUNT(*) AS N
FROM CS5542_WEEK5.PUBLIC.EVENTS
GROUP BY TEAM, CATEGORY
ORDER BY N DESC
'''
pd.read_sql(q, conn)

# %% [markdown]
# ## 4) Close connection

# %%
conn.close()
'closed'
